# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\is2648257\Documents\Videos\T0104\2025-12-15-15-35-49\accelerometer.csv")

column_series = df['GoPro:GPSDateTime']
type(df.column_series[0])
# Out:
# C:\Users\is2648257\AppData\Local\Temp\ipykernel_21852\4148162666.py:3: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r"C:\Users\is2648257\Documents\Videos\T0104\2025-12-15-15-35-49\accelerometer.csv")
# str
